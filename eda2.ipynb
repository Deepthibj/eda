# %%
#steps of eda

# %%
#step1- import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#step-read dataset
df=pd.read_csv("/content/iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#step3- data cleaning

# %%
pip install Klib

# %%
import klib

# %%
klib.data_cleaning(df)#drop duplicates and
# Out:
# Shape of cleaned data: (150, 6) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.01 MB (-100.0%)
#       id  sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0      1              5.1             3.5              1.4             0.2
# 1      2              4.9             3.0              1.4             0.2
# 2      3              4.7             3.2              1.3             0.2
# 3      4              4.6             3.1              1.5             0.2
# 4      5              5.0             3.6              1.4             0.2
# ..   ...              ...             ...              ...             ...
# 145  146              6.7             3.0              5.2             2.3
# 146  147              6.3             2.5              5.0             1.9
# ...

# %%
klib.clean_column_names(df)#cleans and standardize column names
# Out:
#       id  sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0      1              5.1             3.5              1.4             0.2
# 1      2              4.9             3.0              1.4             0.2
# 2      3              4.7             3.2              1.3             0.2
# 3      4              4.6             3.1              1.5             0.2
# 4      5              5.0             3.6              1.4             0.2
# ..   ...              ...             ...              ...             ...
# 145  146              6.7             3.0              5.2             2.3
# 146  147              6.3             2.5              5.0             1.9
# 147  148              6.5             3.0              5.2             2.0
# 148  149              6.2             3.4              5.4             2.3
# 149  150              5.9             3.0              5.1             1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# ...

# %%
klib.convert_datatypes(df)#converts existing to more efficient dtypes, called inside data_cleaning
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
klib.drop_missing(df)#drop missing values
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from matplotlib.colors import Normalize
#step4-univariate analysis
#univariate analysis is analysing a data of one variable
df.Species.value_counts(normalize=True).plot.barh()
# Out:
# <Axes: >

# %%
#step5-bivariate anaysis

# %%
#step6-catagorical values
klib.cat_plot(df)
# Out:
# GridSpec(6, 1)

# %%
#multivariate anaylsis
klib.dist_plot(df)
# Out:
# <Axes: xlabel='Id', ylabel='Density'>

# %%
klib.corr_plot(df)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
#statstical summary
df.describe(include='all').T
# Out:
#                count unique          top freq      mean        std  min  \
# Id             150.0    NaN          NaN  NaN      75.5  43.445368  1.0
# SepalLengthCm  150.0    NaN          NaN  NaN  5.843333   0.828066  4.3
# SepalWidthCm   150.0    NaN          NaN  NaN     3.054   0.433594  2.0
# PetalLengthCm  150.0    NaN          NaN  NaN  3.758667    1.76442  1.0
# PetalWidthCm   150.0    NaN          NaN  NaN  1.198667   0.763161  0.1
# Species          150      3  Iris-setosa   50       NaN        NaN  NaN
#
#                  25%   50%     75%    max
# Id             38.25  75.5  112.75  150.0
# SepalLengthCm    5.1   5.8     6.4    7.9
# SepalWidthCm     2.8   3.0     3.3    4.4
# PetalLengthCm    1.6  4.35     5.1    6.9
# PetalWidthCm     0.3   1.3     1.8    2.5
# Species          NaN   NaN     NaN    NaN

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df1=df.drop('Id',axis=1)
sns.boxplot(df1)
# Out:
# <Axes: >
